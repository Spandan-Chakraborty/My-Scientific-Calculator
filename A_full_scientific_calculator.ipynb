# %% [markdown]
# <a href="https://colab.research.google.com/github/Spandan-Certified/My-Scientific-Calculator/blob/main/A_full_scientific_calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#SPANDAN ULTIMATE CERTIFIED!!!
#FULL SCIENTIFIC CALCULATOR USING PYTHON BASICS.
#LET'S DO THIS
import time as t 
import math as m
import numpy as np
def add():
  x=float(input("Enter first number"))
  y=float(input("Enter second number"))
  z=x+y
  return z
def subtract():
  x=float(input("Enter first number"))
  y=float(input("Enter second number"))
  z=x-y
  return z
def multiply():
  x=float(input("Enter first number"))
  y=float(input("Enter second number"))
  z=x*y
  return z
def divide():
  x=float(input("Enter divident"))
  y=float(input("Enter divisor"))
  z=x/y
  return z
def add2():
  x=float(input("Enter number to add to your result"))
  z=x+res
  return z
def subtract2():
  x=float(input("Enter number to take away from your result"))
  z=x-res
  return z
def multiply2():
  x=float(input("Enter number to multiply to your result"))
  z=x*res
  return z
def divide2():
  x=float(input("Enter number to divide from your result"))
  z=x/res
  return z
def log():
  x=float(input("Enter the number whose log (base 10) you wanna find out"))
  z=m.log(x,10)
  return z
def Antilog():
  x=float(input("Enter the number whose Antilog (base 10) you wanna find out"))
  z=10**x
  return z
def ln():
  x=float(input("Enter the number whose natural logarithm you wanna find out"))
  z=m.log(x)
  return z
def Anti_ln():
  x=float(input("Enter the number whose Antilog (base 10) you wanna find out"))
  z=np.exp(x)
  return z
def Sin():
  ch=int(input("Enter your choice:-\n1 for input in radians\n2 for input in degrees"))
  if ch==1:
    x=float(input("Enter angle in radians:--"))
    z=m.sin(x)
    return z
  if ch==2:
    x=float(input("Enter angle in degrees:--"))
    z=m.sin(m.radians(x))
    return z
def Cos():
  ch=int(input("Enter your choice:-\n1 for input in radians\n2 for input in degrees"))
  if ch==1:
    x=float(input("Enter angle in radians:--"))
    z=m.cos(x)
    return z
  if ch==2:
    x=float(input("Enter angle in degrees:--"))
    z=m.cos(m.radians(x))
    return z
def Tan():
  ch=int(input("Enter your choice:-\n1 for input in radians\n2 for input in degrees"))
  if ch==1:
    x=float(input("Enter angle in radians:--"))
    z=m.tan(x)
    return z
  if ch==2:
    x=float(input("Enter angle in degrees:--"))
    z=m.tan(m.radians(x))
    return z
def Sin_Inv():
  ch=int(input("Enter your choice:-\n1 for Output in radians\n2 for output in degrees"))
  if ch==1:
    x=float(input("Enter value:--"))
    z=m.asin(x)
    return z
  if ch==2:
    x=float(input("Enter value:--"))
    z=m.degrees(m.atan(x))
    return z
def Cos_Inv():
  ch=int(input("Enter your choice:-\n1 for Output in radians\n2 for output in degrees"))
  if ch==1:
    x=float(input("Enter value:--"))
    z=m.acos(x)
    return z
  if ch==2:
    x=float(input("Enter value:--"))
    z=m.degrees(m.acos(x))
    return z
def Tan_Inv():
  ch=int(input("Enter your choice:-\n1 for Output in radians\n2 for output in degrees"))
  if ch==1:
    x=float(input("Enter value:--"))
    z=m.atan(x)
    return z
  if ch==2:
    x=float(input("Enter value:--"))
    z=m.degrees(m.atan(x))
    return z
def Square():
  pass
def Sq_root():
  pass
def Combination():
  pass
def Permutation():
  pass
def Power():
  pass
def root():
  pass
def mode():
  pass
def median():
  pass
def Random():
  pass
def deg_to_Rad():
  pass
def Rad_to_deg():
  pass
def  Armstrong():
  pass
def Spy():
  pass
def  Niven():
  pass
def Palindrome():
  pass

def prRed(skk): print("\033[91m {}\033[00m" .format(skk)) 
def prGreen(skk): print("\033[92m {}\033[00m" .format(skk)) 
def prYellow(skk): print("\033[93m {}\033[00m" .format(skk)) 
def prLightPurple(skk): print("\033[94m {}\033[00m" .format(skk)) 
def prPurple(skk): print("\033[95m {}\033[00m" .format(skk)) 
def prCyan(skk): print("\033[96m {}\033[00m" .format(skk)) 
def prLightGray(skk): print("\033[97m {}\033[00m" .format(skk)) 
def prBlack(skk): print("\033[98m {}\033[00m" .format(skk))

#Main Program
prGreen("Hello Mate!! \nWelcome to My ULtimate Scientific Calculator")
prCyan("Powered By-\nSPANDAN CERTIFIED")


while True:
  ch=int(input("Enter 1 for add operation\nEnter 2 for subtraction operation\nEnter 3 for multiplication operation\nEnter 4 for division operation\n"))
  
  if ch==1:
    print("Adding in a moment....")
    t.sleep(5)
    res=add()
    prRed("The answer is:-")
    print(res)
  elif ch==2:
    print("subtracting in a moment....")
    t.sleep(5)
    res=subtract()
    prRed("The answer is:-")
    print(res)
  elif ch==3:
    print("Multiplying in a moment....")
    t.sleep(5)
    res=multiply()
    prRed("The answer is:-")
    print(res)
  elif ch==4:
    print("dividing in a moment....")
    t.sleep(5)
    res=divide()
    prRed("The answer is:-")
    print(res)  
  elif ch==5:
    print("Finding log in a moment....")
    t.sleep(5)
    res=log()
    prRed("The answer is:-")
    print(res)
  elif ch==6:
    print("Finding antilog moment....")
    t.sleep(5)
    res=Antilog()
    prRed("The answer is:-")
    print(res)
  elif ch==7:
    print("Finding natural logarithm moment....")
    t.sleep(5)
    res=ln()
    prRed("The answer is:-")
    print(res)
  elif ch==8:
    print("Finding antilog in a moment....")
    t.sleep(5)
    res=Anti_ln()
    prRed("The answer is:-")
    print(res)
  elif ch==9:
    print("Finding Sin of angle in a moment....")
    t.sleep(5)
    res=Sin()
    prRed("The answer is:-")
    print(res)
  elif ch==10:
    print("Finding Cos of angle in a moment....")
    t.sleep(5)
    res=Cos()
    prRed("The answer is:-")
    print(res)
  elif ch==11:
    print("Finding Tan of angle in a moment....")
    t.sleep(5)
    res=Tan()
    prRed("The answer is:-")
    print(res)
  elif ch==12:
    print("Finding Sin Inverse in a moment....")
    t.sleep(5)
    res=Sin_Inv()
    prRed("The answer is:-")
    print(res)
  elif ch==99:
    prYellow("Thank You, See ya later Mate!!")
    prCyan("This is SPANDAN CERTIFIED\n#Making Tech Better!!") 
    break;
      






 #'''part2=input("Want to do something more to this result?\nPress Y/y")
#    if part2 in 'Yy':
 #     ch_2=int(input("Enter 1 for add operation\nEnter 2 for subtraction operation\nEnter 3 for multiplication operation\nEnter 4 for division operation"))
  #    if ch==1:
   #     print("Adding in a moment....")
    #    t.sleep(0)
     #   res=add2()
      #  prRed("The answer is:-")
       # print(res)
     # prYellow("Thank You, See ya later Mate!!")
      #prCyan("This is SPANDAN CERTIFIED\n#Making Tech Better!!")
      #break;
    #else:
     # prYellow("Thank You, See ya later Mate!!")
      #prCyan("This is SPANDAN CERTIFIED\n#Making Tech Better!!")
      #break;'''
# Out:
#  Hello Mate!!
# Welcome to My ULtimate Scientific Calculator
#  Powered By-
# SPANDAN CERTIFIED
# Enter 1 for add operation
# Enter 2 for subtraction operation
# Enter 3 for multiplication operation
# Enter 4 for division operation
# 12
# Finding Sin Inverse in a moment....
# Enter your choice:-
# 1 for Output in radians
# 2 for output in degrees2
# Enter value:--0.5
#  The answer is:-
# 26.56505117707799
# Enter 1 for add operation
# Enter 2 for subtraction operation
# Enter 3 for multiplication operation
# Enter 4 for division operation
# 99
#  Thank You, See ya later Mate!!
#  This is SPANDAN CERTIFIED
# #Making Tech Better!!
